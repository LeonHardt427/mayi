# %%
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

df_train = pd.read_csv("E:\\leonhardt\\mayi\\data\\train.csv")

# %%
df_train=df_train.loc[df_train['label']!=-1]
count = df_train.describe().loc["count"]

# %%
col_null = count.sort_values().index[:12]

# %%
df_train.drop(col_null, axis=1, inplace=True)

# %%
df_train.describe()
# Out:
#                label          date             f1             f2  \
# count  994731.000000  9.947310e+05  994731.000000  994731.000000
# mean        0.007436  2.017098e+07       0.726283       0.500948
# std         0.129927  6.011735e+01       0.651947       0.500363
# min        -1.000000  2.017090e+07       0.000000       0.000000
# 25%         0.000000  2.017092e+07       0.000000       0.000000
# 50%         0.000000  2.017101e+07       1.000000       1.000000
# 75%         0.000000  2.017102e+07       1.000000       1.000000
# max         1.000000  2.017110e+07       2.000000       2.000000
#
#                   f3             f4             f5             f6  \
# count  994731.000000  994731.000000  794906.000000  994731.000000
# mean        0.699285       0.525461  100652.575330       0.701303
# std         0.640534       0.523872    4023.235737       0.757799
# min         0.000000       0.000000   10000.000000       0.000000
# 25%         0.000000       0.000000  100802.000000       0.000000
# 50%         1.000000       1.000000  100804.000000       1.000000
# 75%         1.000000       1.000000  100806.000000       1.000000
# max         2.000000       2.000000  150406.000000       4.000000
#
#                   f7             f8      ...                 f288  \
# count  994731.000000  994731.000000      ...        787146.000000
# mean        4.201802       1.404783      ...           159.532191
# std         1.922035       0.579449      ...           149.126719
# min         0.000000       0.000000      ...             1.000000
# 25%         3.000000       1.000000      ...             2.000000
# 50%         4.000000       1.000000      ...           301.000000
# 75%         6.000000       2.000000      ...           302.000000
# max         7.000000       2.000000      ...           302.000000
#
#                 f289           f290           f291           f292  \
# count  787146.000000  787146.000000  787146.000000  787146.000000
# mean      164.423796     174.171849      57.639792     149.509402
# std       152.228807     164.144148      63.122004     142.628265
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       3.000000       2.000000       2.000000
# 50%       301.000000     301.000000      26.000000     184.000000
# 75%       304.000000     306.000000     109.000000     301.000000
# max       388.000000     669.000000     302.000000     302.000000
#
#                 f293           f294           f295           f296  \
# count  787146.000000  787146.000000  787146.000000  787146.000000
# mean      105.056598     105.243853     105.246376      41.244121
# std       100.003140     100.155753     100.153540      45.658241
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       2.000000       2.000000       2.000000
# 50%       164.000000     164.000000     164.000000      17.000000
# 75%       199.000000     199.000000     199.000000      79.000000
# max       299.000000     299.000000     299.000000     280.000000
#
#                 f297
# count  787146.000000
# mean       99.023500
# std        96.240483
# min         1.000000
# 25%         2.000000
# 50%       115.000000
# 75%       194.000000
# max       299.000000
#
# [8 rows x 287 columns]

# %%
df_train.loc[:, "date"].max()
# Out:
# 20171105

# %%
df_train.loc[:, "date"].min()
# Out:
# 20170905

# %%
df_train.dropna(thresh=100, inplace=True)

# %%
df_train.describe()
# Out:
#                label          date             f1             f2  \
# count  862427.000000  8.624270e+05  862427.000000  862427.000000
# mean        0.004429  2.017098e+07       0.607875       0.501167
# std         0.109067  6.027550e+01       0.588621       0.500418
# min        -1.000000  2.017090e+07       0.000000       0.000000
# 25%         0.000000  2.017092e+07       0.000000       0.000000
# 50%         0.000000  2.017101e+07       1.000000       1.000000
# 75%         0.000000  2.017102e+07       1.000000       1.000000
# max         1.000000  2.017110e+07       2.000000       2.000000
#
#                   f3             f4             f5             f6  \
# count  862427.000000  862427.000000  794860.000000  862427.000000
# mean        0.576478       0.500575  100652.538705       0.511580
# std         0.566943       0.500000    4019.616780       0.531638
# min         0.000000       0.000000   10000.000000       0.000000
# 25%         0.000000       0.000000  100802.000000       0.000000
# 50%         1.000000       1.000000  100804.000000       1.000000
# 75%         1.000000       1.000000  100806.000000       1.000000
# max         2.000000       1.000000  150406.000000       4.000000
#
#                   f7             f8      ...                 f288  \
# count  862427.000000  862427.000000      ...        787146.000000
# mean        4.300464       1.404187      ...           159.532191
# std         1.860019       0.579598      ...           149.126719
# min         0.000000       0.000000      ...             1.000000
# 25%         3.000000       1.000000      ...             2.000000
# 50%         4.000000       1.000000      ...           301.000000
# 75%         6.000000       2.000000      ...           302.000000
# max         7.000000       2.000000      ...           302.000000
#
#                 f289           f290           f291           f292  \
# count  787146.000000  787146.000000  787146.000000  787146.000000
# mean      164.423796     174.171849      57.639792     149.509402
# std       152.228807     164.144148      63.122004     142.628265
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       3.000000       2.000000       2.000000
# 50%       301.000000     301.000000      26.000000     184.000000
# 75%       304.000000     306.000000     109.000000     301.000000
# max       388.000000     669.000000     302.000000     302.000000
#
#                 f293           f294           f295           f296  \
# count  787146.000000  787146.000000  787146.000000  787146.000000
# mean      105.056598     105.243853     105.246376      41.244121
# std       100.003140     100.155753     100.153540      45.658241
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       2.000000       2.000000       2.000000
# 50%       164.000000     164.000000     164.000000      17.000000
# 75%       199.000000     199.000000     199.000000      79.000000
# max       299.000000     299.000000     299.000000     280.000000
#
#                 f297
# count  787146.000000
# mean       99.023500
# std        96.240483
# min         1.000000
# 25%         2.000000
# 50%       115.000000
# 75%       194.000000
# max       299.000000
#
# [8 rows x 287 columns]

# %%
train_set = df_train[df_train.loc[:, "date"]<=20171025]
eva_set = df_train[df_train.loc[:, "date"]>20171025]

# %%
del df_train

# %%
import gc
gc.collect()
# Out:
# 219

# %%
import lightgbm as lgb

# %%
train_label = train_set.loc[:, "label"]
eva_label = eva_set.loc[:, "label"]

# %%
train_set.drop(["date", "label"], axis=1, inplace=True)
eva_set.drop(["date", "label"], axis=1, inplace=True)

# %%
train_set.drop(["id"], axis=1, inplace=True)
eva_set.drop(["id"], axis=1, inplace=True)

# %%
lgb_train=lgb.Dataset(train_set,train_label,free_raw_data=False)
lgb_valid=lgb.Dataset(eva_set,eva_label,reference=lgb_train,free_raw_data=False)
params = {'boosting_type': 'gbdt',
          'objective': 'binary', 
          'metric': 'auc', 
          'device': 'cpu', 
          'verbose': 0, 
          'learning_rate': 0.01, 
          'bagging_fraction': 0.8,
          'bagging_freq': 5,
          'feature_fraction': 0.9,
          'lambda_l1': 0.006, 
          'num_leaves': 128,
          'early_stopping_round': 20
}

# %%
from sklearn.metrics import roc_auc_score,roc_curve
def atec_metric(preds, train_data):
    labels = train_data.get_label()
    fpr,tpr,threshhold=roc_curve(labels, preds)
    return 'atec_metric', 0.4*tpr[fpr<=0.001][-1] + 0.3*tpr[fpr<=0.005][-1] + 0.3*tpr[fpr<=0.01][-1], True

gbm=lgb.train(params, lgb_train, num_boost_round=2000, valid_sets=lgb_valid, valid_names='valid_set', feval=atec_metric, verbose_eval=500)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-d90fac39be3f> in <module>()
#       5     return 'atec_metric', 0.4*tpr[fpr<=0.001][-1] + 0.3*tpr[fpr<=0.005][-1] + 0.3*tpr[fpr<=0.01][-1], True
#       6
# ----> 7 gbm=lgb.train(params, lgb_train, num_boost_round=2000, valid_sets=lgb_valid, valid_names='valid_set', feval=atec_metric, verbose_eval=500)
#
# D:\anaconda\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     206             if is_valid_contain_train:
#     207                 evaluation_result_list.extend(booster.eval_train(feval))
# --> 208             evaluation_result_list.extend(booster.eval_valid(feval))
#     209         try:
#     210             for cb in callbacks_after_iter:
#
# D:\anaconda\lib\site-packages\lightgbm\basic.py in eval_valid(self, feval)
#    1647             List with evaluation results.
#    1648         """
# -> 1649         return [item for i in range_(1, self.__num_dataset)
#    1650                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    1651
#
# D:\anaconda\lib\site-packages\lightgbm\basic.py in <listcomp>(.0)
#    1648         """
#    1649         return [item for i in range_(1, self.__num_dataset)
# -> 1650                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    1651
#    1652     def save_model(self, filename, num_iteration=-1):
#
# D:\anaconda\lib\site-packages\lightgbm\basic.py in __inner_eval(self, data_name, data_idx, feval)
#    1912             else:
#    1913                 cur_data = self.valid_sets[data_idx - 1]
# -> 1914             feval_ret = feval(self.__inner_predict(data_idx), cur_data)
#    1915             if isinstance(feval_ret, list):
#    1916                 for eval_name, val, is_higher_better in feval_ret:
#
# <ipython-input-29-d90fac39be3f> in atec_metric(preds, train_data)
#       2 def atec_metric(preds, train_data):
#       3     labels = train_data.get_label()
# ----> 4     fpr,tpr,threshhold=roc_curve(labels, preds)
#       5     return 'atec_metric', 0.4*tpr[fpr<=0.001][-1] + 0.3*tpr[fpr<=0.005][-1] + 0.3*tpr[fpr<=0.01][-1], True
#       6
#
# D:\anaconda\lib\site-packages\sklearn\metrics\ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     532     """
#     533     fps, tps, thresholds = _binary_clf_curve(
# --> 534         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     535
#     536     # Attempt to drop thresholds corresponding to points in between and
#
# D:\anaconda\lib\site-packages\sklearn\metrics\ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     316     if not (y_type == "binary" or
#     317             (y_type == "multiclass" and pos_label is not None)):
# --> 318         raise ValueError("{0} format is not supported".format(y_type))
#     319
#     320     check_consistent_length(y_true, y_score, sample_weight)
#
# ValueError: multiclass format is not supported
